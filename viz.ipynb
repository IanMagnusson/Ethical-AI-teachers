# %%
# Re-import necessary libraries since execution state was reset
import matplotlib.pyplot as plt
import numpy as np



# ## THESE NUMBERS ARE BASED ON THE RAW OUTPUTS; they include the already correct instances
# ## TODO replace this with Zixian's recomputed pass at k numbers

# # Data extracted from previous screenshots
# models = ["OLMo (Base)", "OLMo (Plus)", "Qwen (Base)", "Qwen (Plus)"]
# before = [0.439, 0.368, 0.791, 0.698]  # Before teacher model feedback
# after = [0.614, 0.511, 0.844, 0.743]   # After teacher model feedback
# after_no_cheat = [0.471, 0.410, 0.810, 0.725]  # After Feedback (No Cheat No Question)
# after_retrieval = [0.481, 0.421, 0.817, 0.725]  # After Feedback (Retrieval in Teacher)

# # New data for "Just Feedback" scenarios (cheat, no cheat, retrieval)
# just_feedback_cheat = [0.627, 0.526, 0.844, 0.749]  # Cheat scenario
# just_feedback_no_cheat = [0.384, 0.384, 0.730, 0.725]  # No cheat scenario
# just_feedback_rag = [0.376, 0.370, 0.725, 0.709]  # Retrieval (RAG) scenario

# # New data for "Just Retrieval" scenario
# just_retrieval = [0.466, 0.402, 0.831, 0.754]  # Just retrieval values

# # New data for "Really Just Retrieval" scenario
# really_just_retrieval = [0.413, 0.405, 0.725, 0.720]  # Really just retrieval values

# # Adjusting x positions for the nine sets of bars
# width = 0.09  # Adjust width for nine bars per group
# x = np.arange(len(models))

# fig, ax = plt.subplots(figsize=(20, 6))
# bars1 = ax.bar(x - 4*width, before, width, label="Before Feedback", color='blue', alpha=0.7)
# bars2 = ax.bar(x - 3*width, after, width, label="After Feedback", color='orange', alpha=0.7)
# bars3 = ax.bar(x - 2*width, after_no_cheat, width, label="After Feedback (No Cheat No Question)", color='green', alpha=0.7)
# bars4 = ax.bar(x - width, after_retrieval, width, label="After Feedback (Retrieval in Teacher)", color='purple', alpha=0.7)
# bars5 = ax.bar(x, just_feedback_cheat, width, label="Just Feedback (Cheat)", color='red', alpha=0.7)
# bars6 = ax.bar(x + width, just_feedback_no_cheat, width, label="Just Feedback (No Cheat)", color='cyan', alpha=0.7)
# bars7 = ax.bar(x + 2*width, just_feedback_rag, width, label="Just Feedback (RAG)", color='magenta', alpha=0.7)
# bars8 = ax.bar(x + 3*width, just_retrieval, width, label="Just Retrieval", color='brown', alpha=0.7)
# bars9 = ax.bar(x + 4*width, really_just_retrieval, width, label="Really Just Retrieval", color='darkgreen', alpha=0.7)

# # Labels and Titles
# ax.set_xlabel("Models")
# ax.set_ylabel("Pass@1 Score")
# ax.set_title("Performance Before and After Feedback (Including Just Feedback & Just Retrieval Scenarios)")
# ax.set_xticks(x)
# ax.set_xticklabels(models, rotation=15)
# ax.legend()

# # Display values on bars
# for bars in [bars1, bars2, bars3, bars4, bars5, bars6, bars7, bars8, bars9]:
#     for bar in bars:
#         height = bar.get_height()
#         ax.annotate(f"{height:.3f}",
#                     xy=(bar.get_x() + bar.get_width() / 2, height),
#                     xytext=(0, 3),  # Offset text slightly above bars
#                     textcoords="offset points",
#                     ha='center', va='bottom')

# plt.show()

# %%
import pandas as pd

df_olmo = pd.read_csv('results/pass_at_k_only_retried_instances/allenai--OLMo-2-1124-7B-Instruct_scores.csv')
df_olmo
# Out:
#                                                setup  \
# 0                   mbpp_just_feedback_gpt-3.5-turbo
# 1                    mbpp_just_retrieval_as_feedback
# 2  mbpp_retrieval_as_feedback_gpt-3.5-turbo_no_ch...
# 3  mbpp_just_feedback_rag_teacher_gpt-3.5-turbo_n...
# 4  mbpp_just_feedback_gpt-3.5-turbo_no_cheat_no_q...
# 5  mbpp_with_feedback_gpt-3.5-turbo_no_cheat_no_q...
# 6                   mbpp_with_feedback_gpt-3.5-turbo
# 7  mbpp_with_rag_teacher_feedback_gpt-3.5-turbo_n...
# 8                                           baseline
#
#                               model  base_accuracy  plus_accuracy
# 0  allenai--OLMo-2-1124-7B-Instruct       0.650794       0.526455
# 1  allenai--OLMo-2-1124-7B-Instruct       0.481481       0.404762
# 2  allenai--OLMo-2-1124-7B-Instruct       0.470899       0.402116
# 3  allenai--OLMo-2-1124-7B-Instruct       0.441799       0.370370
# 4  allenai--OLMo-2-1124-7B-Instruct       0.449735       0.383598
# ...

# %%
df_qwen = pd.read_csv('results/pass_at_k_only_retried_instances/Qwen--Qwen2.5-7B-Instruct-1M_scores.csv')
df_qwen
# Out:
#                                                setup  \
# 0                   mbpp_just_feedback_gpt-3.5-turbo
# 1                    mbpp_just_retrieval_as_feedback
# 2  mbpp_retrieval_as_feedback_gpt-3.5-turbo_no_ch...
# 3  mbpp_just_feedback_rag_teacher_gpt-3.5-turbo_n...
# 4  mbpp_just_feedback_gpt-3.5-turbo_no_cheat_no_q...
# 5  mbpp_with_feedback_gpt-3.5-turbo_no_cheat_no_q...
# 6                   mbpp_with_feedback_gpt-3.5-turbo
# 7  mbpp_with_rag_teacher_feedback_gpt-3.5-turbo_n...
# 8                                           baseline
#
#                           model  base_accuracy  plus_accuracy
# 0  Qwen--Qwen2.5-7B-Instruct-1M       0.865079       0.748677
# 1  Qwen--Qwen2.5-7B-Instruct-1M       0.806878       0.719577
# 2  Qwen--Qwen2.5-7B-Instruct-1M       0.838624       0.753968
# 3  Qwen--Qwen2.5-7B-Instruct-1M       0.804233       0.708995
# 4  Qwen--Qwen2.5-7B-Instruct-1M       0.804233       0.724868
# ...

# %%
# Extract relevant data for plotting
scenarios = [
    "mbpp_just_feedback_gpt-3.5-turbo",
    "mbpp_retrieval_as_feedback_gpt-3.5-turbo_no_cheat_no_question",
    "mbpp_just_feedback_rag_teacher_gpt-3.5-turbo_no_cheat_no_question",
    "mbpp_just_feedback_gpt-3.5-turbo_no_cheat_no_question",
    "mbpp_with_feedback_gpt-3.5-turbo_no_cheat_no_question",
    "mbpp_just_feedback_gpt-3.5-turbo",
    "mbpp_with_rag_teacher_feedback_gpt-3.5-turbo_no_cheat_no_question",
    "baseline"
]

# Filter data for the selected scenarios
olmo_filtered = df_olmo[df_olmo["setup"].isin(scenarios)]
qwen_filtered = df_qwen[df_qwen["setup"].isin(scenarios)]

# Models and corresponding accuracy scores
models = ["OLMo (Base)", "OLMo (Plus)", "Qwen (Base)", "Qwen (Plus)"]
data = {
    "Before Feedback": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[-1]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[-1]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[-1]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[-1]]["plus_accuracy"].values[0],
    ],
    "Just Feedback (cheat)": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[0]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[0]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[0]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[0]]["plus_accuracy"].values[0],
    ],
    "Retrieval Feedback": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[1]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[1]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[1]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[1]]["plus_accuracy"].values[0],
    ],
    "Just Feedback (RAG, No Cheat No Question)": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[2]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[2]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[2]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[2]]["plus_accuracy"].values[0],
    ],
    "Just Feedback (No Cheat No Question)": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[3]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[3]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[3]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[3]]["plus_accuracy"].values[0],
    ],
    "After Feedback (No Cheat No Question)": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[4]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[4]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[4]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[4]]["plus_accuracy"].values[0],
    ],
    "After Feedback (cheat)": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[5]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[5]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[5]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[5]]["plus_accuracy"].values[0],
    ],  
    "With RAG Teacher Feedback (No Cheat No Question)": [
        olmo_filtered[olmo_filtered["setup"] == scenarios[6]]["base_accuracy"].values[0],
        olmo_filtered[olmo_filtered["setup"] == scenarios[6]]["plus_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[6]]["base_accuracy"].values[0],
        qwen_filtered[qwen_filtered["setup"] == scenarios[6]]["plus_accuracy"].values[0],
    ],
}

# Convert data to DataFrame for plotting
df_plot = pd.DataFrame(data, index=models)

# Plot the bar chart
fig, ax = plt.subplots(figsize=(16, 8))
width = 0.1  # Adjust width for multiple bars
x = np.arange(len(models))

# Plot each scenario as a separate bar set
for i, (label, values) in enumerate(df_plot.items()):
    ax.bar(x + (i - 3) * width, values, width, label=label, alpha=0.7)

# Labels and Titles
ax.set_xlabel("Models")
ax.set_ylabel("Pass@1 Score")
ax.set_title("Performance Across Different Feedback and Retrieval Scenarios")
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=15)
ax.legend()

# Display values on bars
for i, (label, values) in enumerate(df_plot.items()):
    for j, value in enumerate(values):
        ax.annotate(f"{value:.3f}",
                    xy=(x[j] + (i - 3) * width, value),
                    xytext=(0, 3),  # Offset text slightly above bars
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.show()

# %%
# save the plot into png and pdf
fig.savefig('figures/scores.pdf')
fig.savefig('figures/scores.png')

# %% [markdown]
# ### Plot leakage frequency

# %%
df_olmo = pd.read_csv('results/pass_at_k_only_retried_instances/allenai--OLMo-2-1124-7B-Instruct_eval_metrics.csv')
df_olmo
# Out:
#                                     exp_id                             model  \
# 0                         Teacher Feedback  allenai--OLMo-2-1124-7B-Instruct
# 1  Teacher Feedback (No Cheat No Question)  allenai--OLMo-2-1124-7B-Instruct
# 2                Teacher Feedback with RAG  allenai--OLMo-2-1124-7B-Instruct
# 3                             RAG Feedback  allenai--OLMo-2-1124-7B-Instruct
#
#    base_helpfulness  base_nonleak_helpfulness  base_leakage_freq  \
# 0             0.185                     0.005              0.212
# 1             0.050                     0.045              0.011
# 2             0.056                     0.056              0.003
# 3             0.032                     0.029              0.042
#
#    plus_helpfulness  plus_nonleak_helpfulness  plus_leakage_freq
# 0             0.143                     0.003              0.159
# 1             0.042                     0.037              0.016
# ...

# %%
df_qwen = pd.read_csv('results/pass_at_k_only_retried_instances/Qwen--Qwen2.5-7B-Instruct-1M_eval_metrics.csv')
df_qwen
# Out:
#                                     exp_id                         model  \
# 0                         Teacher Feedback  Qwen--Qwen2.5-7B-Instruct-1M
# 1  Teacher Feedback (No Cheat No Question)  Qwen--Qwen2.5-7B-Instruct-1M
# 2                Teacher Feedback with RAG  Qwen--Qwen2.5-7B-Instruct-1M
# 3                             RAG Feedback  Qwen--Qwen2.5-7B-Instruct-1M
#
#    base_helpfulness  base_nonleak_helpfulness  base_leakage_freq  \
# 0             0.066                     0.003              0.074
# 1             0.026                     0.026              0.013
# 2             0.032                     0.026              0.013
# 3             0.048                     0.040              0.016
#
#    plus_helpfulness  plus_nonleak_helpfulness  plus_leakage_freq
# 0             0.045                     0.003              0.050
# 1             0.026                     0.024              0.026
# 2             0.026                     0.024              0.011
# ...

# %%
# plot leakage frequency
scenarios =  df_olmo['exp_id'].unique()
models = ["OLMo (Base)", "OLMo (Plus)", "Qwen (Base)", "Qwen (Plus)"]

data = {
        exp: [
                df_olmo[df_olmo["exp_id"] == scenarios[i]]["base_leakage_freq"].values[0],
                df_olmo[df_olmo["exp_id"] == scenarios[i]]["plus_leakage_freq"].values[0],
                df_qwen[df_qwen["exp_id"] == scenarios[i]]["base_leakage_freq"].values[0],
                df_qwen[df_qwen["exp_id"] == scenarios[i]]["plus_leakage_freq"].values[0],
                ] 
                for i, exp in enumerate(scenarios)
        }

# %%
# Convert data to DataFrame for plotting
df_plot = pd.DataFrame(data, index=models)

# Plot the bar chart
fig, ax = plt.subplots(figsize=(10, 5))
width = 0.1  # Adjust width for multiple bars
x = np.arange(len(models))

# Plot each scenario as a separate bar set
for i, (label, values) in enumerate(df_plot.items()):
    ax.bar(x + (i - 1) * width, values, width, label=label, alpha=0.7)

# Labels and Titles
ax.set_xlabel("Models")
ax.set_ylabel("Leakage Frequency")
ax.set_title("Leakage Frequency Across Different Feedback and Retrieval Scenarios")
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=15)
ax.legend()

# Display values on bars
for i, (label, values) in enumerate(df_plot.items()):
    for j, value in enumerate(values):
        ax.annotate(f"{value:.3f}",
                    xy=(x[j] + (i - 1) * width, value),
                    xytext=(0, 3),  # Offset text slightly above bars
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.show()

# %%
# save the plot into png and pdf without cutting it off
fig.savefig('figures/leakage_frequency.pdf', bbox_inches='tight')
fig.savefig('figures/leakage_frequency.png', bbox_inches='tight')

# %% [markdown]
# ### Plot helpfulness

# %%
# plot helpfulness
scenarios =  df_olmo['exp_id'].unique()
models = ["OLMo (Base)", "OLMo (Plus)", "Qwen (Base)", "Qwen (Plus)"]

data = {
        exp: [
                df_olmo[df_olmo["exp_id"] == scenarios[i]]["base_helpfulness"].values[0],
                df_olmo[df_olmo["exp_id"] == scenarios[i]]["plus_helpfulness"].values[0],
                df_qwen[df_qwen["exp_id"] == scenarios[i]]["base_helpfulness"].values[0],
                df_qwen[df_qwen["exp_id"] == scenarios[i]]["plus_helpfulness"].values[0],
                ] 
                for i, exp in enumerate(scenarios)
        }

# %%
# Convert data to DataFrame for plotting
df_plot = pd.DataFrame(data, index=models)

# Plot the bar chart
fig, ax = plt.subplots(figsize=(10, 5))
width = 0.1  # Adjust width for multiple bars
x = np.arange(len(models))

# Plot each scenario as a separate bar set
for i, (label, values) in enumerate(df_plot.items()):
    ax.bar(x + (i - 1) * width, values, width, label=label, alpha=0.7)

# Labels and Titles
ax.set_xlabel("Models")
ax.set_ylabel("Helpfulness")
ax.set_title("Helpfulness Across Different Feedback and Retrieval Scenarios")
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=15)
ax.legend()

# Display values on bars
for i, (label, values) in enumerate(df_plot.items()):
    for j, value in enumerate(values):
        ax.annotate(f"{value:.3f}",
                    xy=(x[j] + (i - 1) * width, value),
                    xytext=(0, 3),  # Offset text slightly above bars
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.show()

# %%
# save the plot into png and pdf
fig.savefig('figures/helpfulness.pdf', bbox_inches='tight')
fig.savefig('figures/helpfulness.png', bbox_inches='tight')

# %% [markdown]
# ### Plot non-leaking helpfulness

# %%
# plot helpfulness
scenarios =  df_olmo['exp_id'].unique()
models = ["OLMo (Base)", "OLMo (Plus)", "Qwen (Base)", "Qwen (Plus)"]

data = {
        exp: [
                df_olmo[df_olmo["exp_id"] == scenarios[i]]["base_nonleak_helpfulness"].values[0],
                df_olmo[df_olmo["exp_id"] == scenarios[i]]["plus_nonleak_helpfulness"].values[0],
                df_qwen[df_qwen["exp_id"] == scenarios[i]]["base_nonleak_helpfulness"].values[0],
                df_qwen[df_qwen["exp_id"] == scenarios[i]]["plus_nonleak_helpfulness"].values[0],
                ] 
                for i, exp in enumerate(scenarios)
        }

# %%
# Convert data to DataFrame for plotting
df_plot = pd.DataFrame(data, index=models)

# Plot the bar chart
fig, ax = plt.subplots(figsize=(10, 5))
width = 0.1  # Adjust width for multiple bars
x = np.arange(len(models))

# Plot each scenario as a separate bar set
for i, (label, values) in enumerate(df_plot.items()):
    ax.bar(x + (i - 1) * width, values, width, label=label, alpha=0.7)

# Labels and Titles
ax.set_xlabel("Models")
ax.set_ylabel("Non-leaking Helpfulness")
ax.set_title("Non-leaking Helpfulness Across Different Feedback and Retrieval Scenarios")
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=15)
ax.legend()

# Display values on bars
for i, (label, values) in enumerate(df_plot.items()):
    for j, value in enumerate(values):
        ax.annotate(f"{value:.3f}",
                    xy=(x[j] + (i - 1) * width, value),
                    xytext=(0, 3),  # Offset text slightly above bars
                    textcoords="offset points",
                    ha='center', va='bottom')

plt.show()

# %%
# save the plot into png and pdf
fig.savefig('figures/nonleak_helpfulness.pdf', bbox_inches='tight')
fig.savefig('figures/nonleak_helpfulness.png', bbox_inches='tight')
